# %%
print("Hello World")
# Out:
# Hello World

# %%
"hello world"
# Out:
# 'hello world'

# %%
print("hello world", "cümle", sep=",")
# Out:
# hello world,cümle

# %%
print("nabersin?") #print fonksiyonu yazı çıksını verir.
# Out:
# nabersin?

# %%
yetgen = "ahmet"

print(yetgen)
# Out:
# ahmet

# %%
type("ahmet")
# Out:
# str

# %%
değişken = "ahmet"
print(değişken)
print(değişken [0])
print(değişken [-1])
# Out:
# ahmet
# a
# t

# %%
isim = "ahmet" 
yas = "21"
soyad = "kılıc"

print(f"{isim} {yas} {soyad}")
# Out:
# ahmet 21 kılıc

# %%
ikiSecenek = True
print(ikiSecenek)
print(type(ikiSecenek))
# Out:
# True
# <class 'bool'>

# %%
isim = input("isim giriniz:")
print(f" merhaba {isim}")
# Out:
#  merhaba ahmet

# %%
sayi1 = int(input("birinci sayiyi gir"))
sayi2 = int(input("ikinci sayiyi gir:"))

print(sayi1 + sayi2)
# Out:
# 30
